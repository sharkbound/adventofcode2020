# %%
import questionary as q

q.select('text', ['a', 'b', 'c', 'd']).ask()
# Out:
# ---------------------------------------------------------------------------
# NoConsoleScreenBufferError                Traceback (most recent call last)
# <ipython-input-1-0dfe49b90c70> in <module>
#       1 import questionary as q
#       2
# ----> 3 q.select('text', ['a', 'b', 'c', 'd']).ask()
#
# D:\programs\miniconda\envs\python38\lib\site-packages\questionary\prompts\select.py in select(message, choices, default, qmark, style, use_shortcuts, use_arrow_keys, use_indicator, use_pointer, instruction, **kwargs)
#     141         return tokens
#     142
# --> 143     layout = common.create_inquirer_layout(ic, get_prompt_tokens, **kwargs)
#     144
#     145     bindings = KeyBindings()
#
# D:\programs\miniconda\envs\python38\lib\site-packages\questionary\prompts\common.py in create_inquirer_layout(ic, get_prompt_tokens, **kwargs)
#     467     """Create a layout combining question and inquirer selection."""
#     468
# ...
